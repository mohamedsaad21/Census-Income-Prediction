# %% [markdown]
# <html>
# <body>
# <hr style="border: 2px solid #1f88c0ff; width: 90%;">
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  Customer Churn Predection
# </h1>
# <hr style="border: 2px solid #1f88c0ff; width: 90%;">
# <p style="text-align:center;">
#   <img src='Customer-Churn.png' alt='Cinema'
#        style="border-radius:20px; border:3px solid black;">
# </p>
# </body>
# </html>

# %% [markdown]
# # 🟢 Customer Churn Prediction
#
#
# ## 1️⃣ Problem Definition
# **Customer Churn** refers to customers who stop using a company's product or service.
# The goal is to **predict which customers are likely to churn** based on historical behavior.
#
#
# ## 2️⃣ Why This Problem is Important
# - Retaining existing customers is **cheaper than acquiring new ones**.
# - Helps companies **increase revenue and improve customer satisfaction**.
# - Enables **targeted retention strategies** for at-risk customers.
#
#
# ## 3️⃣ How Machine Learning Can Help
# - ML models can **analyze historical customer data** to detect churn patterns.
# - **Predictive models** identify high-risk customers **before they leave**.
# - Supports **data-driven decision making** in marketing and customer support.
#
#
# ## 4️⃣ Data Description
# | Feature | Type | Description |
# |---------|------|-------------|
# | CustomerID | Identifier | Unique ID for each customer |
# | Age | Numeric | Age of the customer |
# | Gender | Categorical | Male / Female |
# | Tenure | Numeric | Months customer has been with company |
# | Usage Frequency | Numeric | How often customer uses the service |
# | Support Calls | Numeric | Number of calls to support |
# | Payment Delay | Numeric | Delays in payments |
# | Subscription Type | Categorical | Basic / Standard / Premium |
# | Contract Length | Categorical | Monthly / Quarterly / Yearly |
# | Total Spend | Numeric | Total amount spent by the customer |
# | Last Interaction | Numeric | Days since last interaction |
# | Churn | Target | 0 = Active, 1 = Churned |

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  1.Importing
# </h1>
#
# </body>
# </html>

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  2.Reading Data
# </h1>
#
# </body>
# </html>

# %%
train = pd.read_csv('D:\Track projects\Customer_churn\datasets\customer_churn_dataset-training-master.csv')
test = pd.read_csv('D:\Track projects\Customer_churn\datasets\customer_churn_dataset-testing-master.csv')

# %%
print(f"Train Shape : {train.shape}")
print(f"Test Shape : {test.shape}")
# Out:
# Train Shape : (440833, 12)
# Test Shape : (64374, 12)

# %%
df = pd.concat([train , test] , axis = 0)
df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
df.shape
# Out:
# (505207, 12)

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  3.Exploratory Data Analysis
# </h1>
#
# </body>
# </html>

# %%
print(df.columns)
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
df.drop('CustomerID' , axis = 1 , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 505207 entries, 0 to 64373
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Age                505206 non-null  float64
#  1   Gender             505206 non-null  object
#  2   Tenure             505206 non-null  float64
#  3   Usage Frequency    505206 non-null  float64
#  4   Support Calls      505206 non-null  float64
#  5   Payment Delay      505206 non-null  float64
#  6   Subscription Type  505206 non-null  object
#  7   Contract Length    505206 non-null  object
#  8   Total Spend        505206 non-null  float64
#  9   Last Interaction   505206 non-null  float64
#  10  Churn              505206 non-null  float64
# dtypes: float64(8), object(3)
# memory usage: 46.3+ MB

# %%
df.describe()
# Out:
#                  Age         Tenure  Usage Frequency  Support Calls  \
# count  505206.000000  505206.000000    505206.000000  505206.000000
# mean       39.704172      31.350435        15.714825       3.833317
# std        12.670577      17.237482         8.619323       3.133603
# min        18.000000       1.000000         1.000000       0.000000
# 25%        29.000000      16.000000         8.000000       1.000000
# 50%        40.000000      32.000000        16.000000       3.000000
# 75%        49.000000      46.000000        23.000000       6.000000
# max        65.000000      60.000000        30.000000      10.000000
#
#        Payment Delay    Total Spend  Last Interaction          Churn
# count  505206.000000  505206.000000     505206.000000  505206.000000
# mean       13.496843     620.072766         14.610581       0.555203
# std         8.451187     245.319256          8.608286       0.496944
# min         0.000000     100.000000          1.000000       0.000000
# 25%         6.000000     446.000000          7.000000       0.000000
# 50%        13.000000     648.900000         14.000000       1.000000
# 75%        20.000000     824.000000         22.000000       1.000000
# max        30.000000    1000.000000         30.000000       1.000000

# %%
df.describe(include= 'object')
# Out:
#         Gender Subscription Type Contract Length
# count   505206            505206          505206
# unique       2                 3               3
# top       Male          Standard          Annual
# freq    280273            170630          198608

# %%
for col in df.columns :
    print(col)
    print(df[col].unique())
# Out:
# Age
# [30. 65. 55. 58. 23. 51. 39. 64. 29. 52. 22. 48. 24. 49. 19. 47. 42. 57.
#  27. 59. 21. 60. 35. 18. 56. 20. 63. 25. 28. 32. 38. 37. 31. 53. 41. 33.
#  26. 36. 44. 34. 61. 40. 45. 46. 54. 43. 50. 62. nan]
# Gender
# ['Female' 'Male' nan]
# Tenure
# [39. 49. 14. 38. 32. 33. 37. 12.  3. 18. 21. 41. 35.  4. 56. 44. 15. 55.
#  43. 52. 26.  2. 29. 59. 40. 51. 53. 24. 30.  6. 28. 17. 60.  7. 34. 10.
#   5. 45. 54. 58. 25. 13. 47. 31. 22. 19. 23.  1.  8. 46. 16. 50. 48. 11.
#  42. 27.  9. 20. 57. 36. nan]
# Usage Frequency
# [14.  1.  4. 21. 20. 25. 12.  8.  5.  9.  6. 17. 23. 13. 16. 27.  2. 28.
#  29. 15. 24.  3. 22. 26. 30.  7. 11. 18. 19. 10. nan]
# Support Calls
# [ 5. 10.  6.  7.  9.  3.  4.  2.  0.  1.  8. nan]
# Payment Delay
# [18.  8.  7. 26. 16. 15.  4. 11. 30. 25. 13. 22.  5. 14.  3. 10. 28.  2.
#   6. 27. 12. 29. 17. 24.  9. 23. 21.  1.  0. 20. 19. nan]
# Subscription Type
# ['Standard' 'Basic' 'Premium' nan]
# Contract Length
# ['Annual' 'Monthly' 'Quarterly' nan]
# Total Spend
# [932.   557.   185.   ... 829.59 804.3  959.47]
# Last Interaction
# [17.  6.  3. 29. 20.  8. 24. 30. 13. 18. 19. 23.  4. 16. 10. 21. 22.  2.
#  15. 28. 26.  7.  1.  9.  5. 14. 11. 12. 27. 25. nan]
# Churn
# [ 1.  0. nan]

# %% [markdown]
# ## dentify each feature as:
# o Numerical
# o Binary categorical
# o Ordinal categorical
# o Nominal categorical

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  4.Detect and Handle Missing Values
# </h1>
#
# </body>
# </html>

# %%
df.isna().sum()
# Out:
# Age                  1
# Gender               1
# Tenure               1
# Usage Frequency      1
# Support Calls        1
# Payment Delay        1
# Subscription Type    1
# Contract Length      1
# Total Spend          1
# Last Interaction     1
# Churn                1
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  5.Detect outlier
# </h1>
#
# </body>
# </html>

# %%
num_col = df.select_dtypes(include='number').columns
cat_col = df.select_dtypes(include='object').columns

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data=df[num_col])

plt.title('Boxplot for Outlier Detection')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  6. Analysis and Visualizations
# </h1>
#
# </body>
# </html>

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(5, 5))

sns.countplot(
    data=df,
    x="Churn" ,width =.4
)

plt.title("Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Count")

plt.show()

# %%
plt.figure(figsize=(15, 10))

for i, col in enumerate(num_col, 1):
    plt.subplot(2 , 4, i)
    sns.histplot(data=df, x=col, kde=True, bins=30)  
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for i, col in enumerate(cat_col, 1):
    plt.subplot(1 , 3 , i)
    sns.countplot(data=df, x=col , hue = 'Churn')  
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %%
corr = df[num_col].corr()

sns.heatmap(data = corr , annot= True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  7.Encoding
# </h1>
#
# </body>
# </html>

# %%
from sklearn.preprocessing import OneHotEncoder

df_encoded = df.copy()

ohe = OneHotEncoder(
    drop='first',
    sparse_output=False
)

gender_encoded = ohe.fit_transform(df_encoded[['Gender']])

gender_df = pd.DataFrame(
    gender_encoded,
    columns=ohe.get_feature_names_out(['Gender']),
    index=df_encoded.index
)

df_encoded = pd.concat([df_encoded.drop('Gender', axis=1), gender_df], axis=1)

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_cols = ['Subscription Type', 'Contract Length']

oe = OrdinalEncoder(
    categories=[
        ['Basic', 'Standard', 'Premium'],        
        ['Monthly', 'Quarterly', 'Annual']       
    ]
)

df_encoded[ordinal_cols] = oe.fit_transform(df_encoded[ordinal_cols])

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  8.Splitting Data
# </h1>
#
# </body>
# </html>

# %%
from sklearn.model_selection import train_test_split

X = df_encoded.drop('Churn' , axis= 1)
y = df_encoded['Churn']

X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.15, random_state=42, stratify=y
)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.176, random_state=42, stratify=y_temp
)
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (353846, 10)
# (353846,)
# (75579, 10)
# (75579,)
# (75781, 10)
# (75781,)

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  9.Scaling Numerical Features
# </h1>
#
# </body>
# </html>

# %%
from sklearn.preprocessing import StandardScaler 


scaled_col = ['Age', 'Tenure', 'Usage Frequency', 'Support Calls', 'Payment Delay',
       'Total Spend', 'Last Interaction']
scaler = StandardScaler()
X_train[scaled_col] = scaler.fit_transform(X_train[scaled_col])
X_val[scaled_col] = scaler.transform(X_val[scaled_col])
X_test[scaled_col] = scaler.transform(X_test[scaled_col])

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  10.Handle Imbalanced problem
# </h1>
#
# </body>
# </html>

# %%
from imblearn.under_sampling import  RandomUnderSampler

rus = RandomUnderSampler(sampling_strategy='auto',
    random_state=42
)

X_train, y_train = rus.fit_resample(
    X_train, y_train
)

# %% [markdown]
# <html>
# <body>
#
# <h1 style="text-align:center; font-family: 'Arial', sans-serif; color:#ffffff;">
#  11.Models & Predicitions
# </h1>
#
# </body>
# </html>

# %% [markdown]
# # Basic Models

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score , classification_report ,confusion_matrix


Basic_models = {
    "Logistic Regression": LogisticRegression(),
    "Naive Bayes": GaussianNB(),
    "KNN": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42)
}

# %%
results = []

for name, model in Basic_models.items():
    model.fit(X_train, y_train)  

    y_pred = model.predict(X_val)
    
    
    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_val, y_pred),
        "Precision": precision_score(y_val, y_pred),
        "Recall": recall_score(y_val, y_pred),
        "F1-score": f1_score(y_val, y_pred)
    })
    print(f"{name} Acc :{accuracy_score(y_val, y_pred):.2f}")
    print(classification_report(y_val, y_pred))
    print("***************************************")

results_df = pd.DataFrame(results)
results_df
# Out:
# Logistic Regression Acc :0.83
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.85      0.82     33617
#          1.0       0.87      0.81      0.84     41962
#
#     accuracy                           0.83     75579
#    macro avg       0.83      0.83      0.83     75579
# weighted avg       0.83      0.83      0.83     75579
#
# ***************************************
# KNN Acc :0.89
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.88      0.88     33617
#          1.0       0.90      0.90      0.90     41962
#
#     accuracy                           0.89     75579
#    macro avg       0.89      0.89      0.89     75579
# weighted avg       0.89      0.89      0.89     75579
#
# ***************************************
# Naive Bayes Acc :0.87
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.88      0.85     33617
#          1.0       0.90      0.85      0.88     41962
#
#     accuracy                           0.87     75579
#    macro avg       0.86      0.87      0.86     75579
# weighted avg       0.87      0.87      0.87     75579
#
# ***************************************
# Decision Tree Acc :0.87
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.89      0.86     33617
#          1.0       0.90      0.86      0.88     41962
#
#     accuracy                           0.87     75579
#    macro avg       0.87      0.87      0.87     75579
# weighted avg       0.87      0.87      0.87     75579
#
# ***************************************
# Random Forest Acc :0.94
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.86      0.92     33617
#          1.0       0.90      1.00      0.95     41962
#
#     accuracy                           0.94     75579
#    macro avg       0.95      0.93      0.93     75579
# weighted avg       0.94      0.94      0.94     75579
#
# ***************************************
#                  Model  Accuracy  Precision    Recall  F1-score
# 0  Logistic Regression  0.827809   0.873311  0.806921  0.838804
# 1                  KNN  0.888911   0.900434  0.899361  0.899897
# 2          Naive Bayes  0.865201   0.901633  0.849936  0.875021
# 3        Decision Tree  0.873232   0.903985  0.863376  0.883214
# 4        Random Forest  0.935961   0.897571  0.998618  0.945402

# %% [markdown]
# #  Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV


param_grids = {
    "Logistic Regression": {
        "C": [0.01, 0.1, 1, 10],
        "solver": ["lbfgs"],
        "max_iter": [200 ,500 ,1000]
    },
    "Naive Bayes": {
        
    },
    "KNN": {
        "n_neighbors": [3, 5, 7, 9],
        "weights": ["uniform", "distance"]
    },
    
    "Decision Tree": {
        "max_depth": [3, 5, 10, None],
        "min_samples_split": [2, 5, 10]
    },
    "Random Forest": {
        "n_estimators": [50, 100, 200],
        "max_depth": [3, 5, 10, None],
        "min_samples_split": [2, 5, 10]
    },
    
}

# %%
tuned_models = {}
tuned_results = []

for name, model in Basic_models.items():
    print(f"Running GridSearchCV for {name}...")
    
    if name in param_grids and param_grids[name]:  
        grid = GridSearchCV(
            estimator=model,
            param_grid=param_grids[name],
            scoring="f1",
            cv=5,
            n_jobs=-1
        )
        grid.fit(X_train, y_train)
        best_model = grid.best_estimator_
        best_params = grid.best_params_
    else:
        model.fit(X_train, y_train)
        best_model = model
        best_params = "No tuning needed"
    

    tuned_models[name] = {
        "model": best_model,
        "best_params": best_params
    }
    
    y_val_pred = best_model.predict(X_val)
    
    tuned_results.append({
        "Model": name +" Tunning",
        "Accuracy": accuracy_score(y_val, y_val_pred),
        "Precision": precision_score(y_val, y_val_pred),
        "Recall": recall_score(y_val, y_val_pred),
        "F1-score": f1_score(y_val, y_val_pred),
        "Best_Params": best_params
    })
    print(f"{name} Acc :{accuracy_score(y_val, y_val_pred):.2f}")
    print(classification_report(y_val, y_val_pred))
    print("***************************************")


tuned_results_df = pd.DataFrame(tuned_results)
tuned_results_df
# Out:
# Running GridSearchCV for Logistic Regression...
# Logistic Regression Acc :0.83
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.85      0.82     33617
#          1.0       0.87      0.81      0.84     41962
#
#     accuracy                           0.83     75579
#    macro avg       0.83      0.83      0.83     75579
# weighted avg       0.83      0.83      0.83     75579
#
# ***************************************
# Running GridSearchCV for Naive Bayes...
# Naive Bayes Acc :0.87
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.88      0.85     33617
#          1.0       0.90      0.85      0.88     41962
#
#     accuracy                           0.87     75579
#    macro avg       0.86      0.87      0.86     75579
# weighted avg       0.87      0.87      0.87     75579
#
# ***************************************
# Running GridSearchCV for KNN...
# KNN Acc :0.89
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.88      0.88     33617
#          1.0       0.90      0.91      0.90     41962
#
#     accuracy                           0.89     75579
#    macro avg       0.89      0.89      0.89     75579
# weighted avg       0.89      0.89      0.89     75579
#
# ***************************************
# Running GridSearchCV for Decision Tree...
# Decision Tree Acc :0.93
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.86      0.92     33617
#          1.0       0.90      0.99      0.94     41962
#
#     accuracy                           0.93     75579
#    macro avg       0.94      0.93      0.93     75579
# weighted avg       0.94      0.93      0.93     75579
#
# ***************************************
# Running GridSearchCV for Random Forest...
# Random Forest Acc :0.94
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.86      0.92     33617
#          1.0       0.90      1.00      0.95     41962
#
#     accuracy                           0.94     75579
#    macro avg       0.95      0.93      0.93     75579
# weighted avg       0.94      0.94      0.94     75579
#
# ***************************************
#                          Model  Accuracy  Precision    Recall  F1-score  \
# 0  Logistic Regression Tunning  0.827809   0.873311  0.806921  0.838804
# 1          Naive Bayes Tunning  0.865201   0.901633  0.849936  0.875021
# 2                  KNN Tunning  0.893079   0.900911  0.907202  0.904046
# 3        Decision Tree Tunning  0.932865   0.897894  0.991874  0.942547
# 4        Random Forest Tunning  0.936133   0.897514  0.999047  0.945563
#
#                                          Best_Params
# 0     {'C': 0.1, 'max_iter': 200, 'solver': 'lbfgs'}
# 1                                   No tuning needed
# 2          {'n_neighbors': 9, 'weights': 'distance'}
# 3          {'max_depth': 10, 'min_samples_split': 2}
# 4  {'max_depth': None, 'min_samples_split': 10, '...

# %%
all_models = pd.concat([results_df , tuned_results_df] , axis =0).sort_values('Model').reset_index()
all_models
# Out:
#    index                        Model  Accuracy  Precision    Recall  \
# 0      3                Decision Tree  0.873232   0.903985  0.863376
# 1      3        Decision Tree Tunning  0.932865   0.897894  0.991874
# 2      1                          KNN  0.888911   0.900434  0.899361
# 3      2                  KNN Tunning  0.893079   0.900911  0.907202
# 4      0          Logistic Regression  0.827809   0.873311  0.806921
# 5      0  Logistic Regression Tunning  0.827809   0.873311  0.806921
# 6      2                  Naive Bayes  0.865201   0.901633  0.849936
# 7      1          Naive Bayes Tunning  0.865201   0.901633  0.849936
# 8      4                Random Forest  0.935961   0.897571  0.998618
# 9      4        Random Forest Tunning  0.936133   0.897514  0.999047
#
#    F1-score                                        Best_Params
# 0  0.883214                                                NaN
# 1  0.942547          {'max_depth': 10, 'min_samples_split': 2}
# 2  0.899897                                                NaN
# 3  0.904046          {'n_neighbors': 9, 'weights': 'distance'}
# 4  0.838804                                                NaN
# 5  0.838804     {'C': 0.1, 'max_iter': 200, 'solver': 'lbfgs'}
# 6  0.875021                                                NaN
# 7  0.875021                                   No tuning needed
# 8  0.945402                                                NaN
# 9  0.945563  {'max_depth': None, 'min_samples_split': 10, '...

# %% [markdown]
# #  More Advanced Algorithims
# ### [ SVC , XGboost , Adaboost ,LightGBoost ,ExtraTree ]

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import  SVC
from lightgbm import LGBMClassifier
